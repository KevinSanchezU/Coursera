# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on Github

# %% [markdown]
# **Sanchez Kevin**
#
# Currently studying computing engineering in college

# %% [markdown]
# *I am interested in data science because i find databases, statistics and the idea of finding patterns in data interesting*

# %% [markdown]
# ### The code in the next cell check if a number is even or odd

# %%
number = int(input("Ingresa un número: "))
if number % 2 == 0:
    print("El número es par")
else:
    print("El número es impar")

# %% [markdown]
# Horizontal rule
# ***
#
# Numbered list
# 1. One
# 3. Two
# 2. Three
#
# Blockquotes
#
# > This is a blockquote
#
# > This is a very very very very very very very very very very very very very very very very long blockquote
